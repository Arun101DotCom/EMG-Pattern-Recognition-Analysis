# %%
import pandas as pd  # For data handling
import numpy as np  # For numerical operations
from sklearn.model_selection import train_test_split  # For splitting the data
from sklearn.preprocessing import StandardScaler  # For scaling the data
from sklearn.svm import SVC  # For the SVM model
from sklearn.metrics import accuracy_score, classification_report  # For model evaluation
import matplotlib.pyplot as plt  # For plotting



# List of data files with paths
files = {
    


    
    'MAV_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mav_features.csv',
    'RMS_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_rms_features.csv',
    'VAR_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_var_features.csv',
    'WL_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wl_features.csv',
    'ZC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_zc_features.csv',
    'SSC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_ssc_features.csv',
    'WAMP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wamp_features.csv',
    
    
    'MNF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mnf_features.csv',
    'MDF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mdf_features.csv',
    'PF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_pf_features.csv',
    'PSD_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_psd_features.csv',
    'TP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tp_features.csv',
    
    
    
    'WT_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tf_energy_features.csv',
    
    
    'Combined_Time_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Domain_Feature.csv',
    'Combined_Fequency_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Frequency_Domain_Feature.csv',
    'combined_Time_Freq_& Tim-Freq_domain':r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv',
    
}






# Function to train and evaluate a classifier on a given dataset
def train_and_evaluate(file, label='Class'):
    try:
        # Step 1: Load the dataset
        data = pd.read_csv(file)
        
        # Step 2: Split the dataset into features and target variable
        X = data.drop(label, axis=1)
        Y = data[label]

        # Step 3: Split the dataset into training and testing sets
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

        # Step 4: Standardize the features
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Step 5: Train the SVM Classifier
        classifier = SVC(kernel='linear', random_state=42)
        classifier.fit(X_train, Y_train)

        # Step 6: Predict the labels on the test set
        Y_pred = classifier.predict(X_test)

        # Step 7: Evaluate the classifier accuracy for testing data
        accuracy_test = accuracy_score(Y_test, Y_pred)
        print(f'Accuracy for testing on {file}: {accuracy_test:.2%}')

        # Step 8: Predict the labels on the training set
        Y_train_pred = classifier.predict(X_train)

        # Evaluate the classifier accuracy for training data
        accuracy_train = accuracy_score(Y_train, Y_train_pred)
        print(f'Accuracy for training on {file}: {accuracy_train:.2%}')

        # Plot the accuracy (optional)
        plt.figure(figsize=(5, 4))  # Adjust figure size as desired
        plt.bar(['Training', 'Testing'], [accuracy_train, accuracy_test], color=['skyblue', 'lightgreen'])
        plt.xlabel('Data Split')
        plt.ylabel('Accuracy')
        plt.title(f'Training vs Testing Accuracy for {file}')
        plt.grid(axis='y')
        plt.tight_layout()  # Adjust layout for better readability
        plt.show()

        # Print classification report
        print('Classification Report:')
        print(classification_report(Y_test, Y_pred))

    except FileNotFoundError:
        print(f"File not found: {file}")
    except Exception as e:
        print(f"An error occurred while processing {file}: {e}")

# Train and evaluate a classifier for each dataset
for label, file in files.items():
    train_and_evaluate(file)
# Out:
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mav_features.csv: 59.55%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mav_features.csv: 60.03%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.98      0.81      3054
#            1       0.47      0.31      0.37       285
#            2       0.45      0.35      0.40       276
#            3       0.38      0.15      0.21       302
#            4       0.46      0.42      0.44       275
#            5       0.42      0.38      0.40       267
#            6       0.47      0.34      0.40       314
#            7       0.27      0.16      0.20       293
#            8       0.41      0.27      0.33       297
#            9       0.24      0.12      0.16       264
#           10       0.24      0.05      0.08       259
#           11       0.34      0.36      0.35       247
#           12       0.28      0.08      0.12       288
#
#     accuracy                           0.60      6421
#    macro avg       0.40      0.30      0.33      6421
# weighted avg       0.53      0.60      0.54      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_rms_features.csv: 60.83%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_rms_features.csv: 61.25%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82      3054
#            1       0.48      0.33      0.39       285
#            2       0.51      0.40      0.45       276
#            3       0.39      0.18      0.24       302
#            4       0.48      0.46      0.47       275
#            5       0.47      0.45      0.46       267
#            6       0.44      0.35      0.39       314
#            7       0.25      0.15      0.18       293
#            8       0.44      0.31      0.36       297
#            9       0.29      0.14      0.19       264
#           10       0.22      0.05      0.08       259
#           11       0.38      0.38      0.38       247
#           12       0.36      0.12      0.18       288
#
#     accuracy                           0.61      6421
#    macro avg       0.42      0.33      0.35      6421
# weighted avg       0.54      0.61      0.56      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_var_features.csv: 60.21%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_var_features.csv: 60.05%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.98      0.81      3054
#            1       0.35      0.32      0.34       285
#            2       0.43      0.38      0.40       276
#            3       0.30      0.28      0.29       302
#            4       0.58      0.51      0.54       275
#            5       0.69      0.46      0.55       267
#            6       0.49      0.27      0.35       314
#            7       0.34      0.06      0.11       293
#            8       0.38      0.29      0.33       297
#            9       0.37      0.09      0.14       264
#           10       0.29      0.06      0.10       259
#           11       0.37      0.29      0.33       247
#           12       0.35      0.11      0.17       288
#
#     accuracy                           0.60      6421
#    macro avg       0.43      0.32      0.34      6421
# weighted avg       0.54      0.60      0.54      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wl_features.csv: 59.24%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wl_features.csv: 58.58%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.98      0.81      3054
#            1       0.36      0.27      0.31       285
#            2       0.47      0.36      0.41       276
#            3       0.39      0.21      0.27       302
#            4       0.39      0.47      0.43       275
#            5       0.44      0.37      0.40       267
#            6       0.48      0.27      0.35       314
#            7       0.33      0.14      0.20       293
#            8       0.44      0.27      0.34       297
#            9       0.25      0.08      0.12       264
#           10       0.10      0.01      0.01       259
#           11       0.38      0.38      0.38       247
#           12       0.34      0.09      0.14       288
#
#     accuracy                           0.59      6421
#    macro avg       0.39      0.30      0.32      6421
# weighted avg       0.52      0.59      0.53      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_zc_features.csv: 47.56%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_zc_features.csv: 46.71%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.64      3054
#            1       0.00      0.00      0.00       285
#            2       0.00      0.00      0.00       276
#            3       0.00      0.00      0.00       302
#            4       0.00      0.00      0.00       275
#            5       0.00      0.00      0.00       267
#            6       0.00      0.00      0.00       314
#            7       0.00      0.00      0.00       293
#            8       0.00      0.00      0.00       297
#            9       0.00      0.00      0.00       264
#           10       0.00      0.00      0.00       259
#           11       0.00      0.00      0.00       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.48      6421
#    macro avg       0.04      0.08      0.05      6421
# weighted avg       0.23      0.48      0.31      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_ssc_features.csv: 47.56%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_ssc_features.csv: 46.71%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.64      3054
#            1       0.00      0.00      0.00       285
#            2       0.00      0.00      0.00       276
#            3       0.00      0.00      0.00       302
#            4       0.00      0.00      0.00       275
#            5       0.00      0.00      0.00       267
#            6       0.00      0.00      0.00       314
#            7       0.00      0.00      0.00       293
#            8       0.00      0.00      0.00       297
#            9       0.00      0.00      0.00       264
#           10       0.00      0.00      0.00       259
#           11       0.00      0.00      0.00       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.48      6421
#    macro avg       0.04      0.08      0.05      6421
# weighted avg       0.23      0.48      0.31      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wamp_features.csv: 55.07%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wamp_features.csv: 54.31%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.99      0.74      3054
#            1       0.30      0.09      0.14       285
#            2       0.53      0.11      0.19       276
#            3       0.19      0.03      0.05       302
#            4       0.39      0.49      0.44       275
#            5       0.51      0.33      0.40       267
#            6       0.49      0.21      0.29       314
#            7       0.30      0.06      0.10       293
#            8       0.40      0.17      0.24       297
#            9       0.35      0.09      0.14       264
#           10       0.00      0.00      0.00       259
#           11       0.28      0.13      0.17       247
#           12       0.36      0.15      0.21       288
#
#     accuracy                           0.55      6421
#    macro avg       0.36      0.22      0.24      6421
# weighted avg       0.46      0.55      0.46      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mnf_features.csv: 50.05%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mnf_features.csv: 49.28%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.97      0.77      3054
#            1       0.08      0.07      0.08       285
#            2       0.29      0.07      0.12       276
#            3       0.22      0.07      0.11       302
#            4       0.14      0.45      0.21       275
#            5       0.21      0.03      0.05       267
#            6       0.12      0.13      0.13       314
#            7       0.03      0.00      0.01       293
#            8       0.00      0.00      0.00       297
#            9       0.00      0.00      0.00       264
#           10       0.00      0.00      0.00       259
#           11       0.11      0.00      0.01       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.50      6421
#    macro avg       0.14      0.14      0.11      6421
# weighted avg       0.36      0.50      0.40      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mdf_features.csv: 51.97%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mdf_features.csv: 51.06%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.81      3054
#            1       0.11      0.07      0.08       285
#            2       0.35      0.28      0.31       276
#            3       0.34      0.11      0.17       302
#            4       0.14      0.50      0.22       275
#            5       0.19      0.05      0.08       267
#            6       0.17      0.26      0.20       314
#            7       0.09      0.01      0.02       293
#            8       0.11      0.01      0.01       297
#            9       0.12      0.02      0.03       264
#           10       0.00      0.00      0.00       259
#           11       0.33      0.01      0.02       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.52      6421
#    macro avg       0.20      0.18      0.15      6421
# weighted avg       0.41      0.52      0.44      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_pf_features.csv: 49.07%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_pf_features.csv: 48.83%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.98      0.71      3054
#            1       0.17      0.03      0.05       285
#            2       0.00      0.00      0.00       276
#            3       0.09      0.10      0.09       302
#            4       0.17      0.31      0.22       275
#            5       0.00      0.00      0.00       267
#            6       0.00      0.00      0.00       314
#            7       0.33      0.01      0.01       293
#            8       0.14      0.02      0.04       297
#            9       0.09      0.01      0.01       264
#           10       0.00      0.00      0.00       259
#           11       0.19      0.09      0.13       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.49      6421
#    macro avg       0.13      0.12      0.10      6421
# weighted avg       0.32      0.49      0.36      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_psd_features.csv: 61.42%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_psd_features.csv: 62.27%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83      3054
#            1       0.42      0.33      0.37       285
#            2       0.50      0.45      0.47       276
#            3       0.36      0.21      0.26       302
#            4       0.48      0.51      0.49       275
#            5       0.48      0.52      0.50       267
#            6       0.46      0.31      0.37       314
#            7       0.37      0.12      0.18       293
#            8       0.41      0.31      0.35       297
#            9       0.30      0.17      0.22       264
#           10       0.14      0.03      0.06       259
#           11       0.40      0.39      0.40       247
#           12       0.37      0.12      0.18       288
#
#     accuracy                           0.61      6421
#    macro avg       0.42      0.34      0.36      6421
# weighted avg       0.55      0.61      0.56      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tp_features.csv: 61.42%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tp_features.csv: 62.27%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83      3054
#            1       0.42      0.33      0.37       285
#            2       0.50      0.45      0.47       276
#            3       0.36      0.21      0.26       302
#            4       0.48      0.51      0.49       275
#            5       0.48      0.52      0.50       267
#            6       0.46      0.31      0.37       314
#            7       0.37      0.12      0.18       293
#            8       0.41      0.31      0.35       297
#            9       0.30      0.17      0.22       264
#           10       0.14      0.03      0.06       259
#           11       0.40      0.39      0.40       247
#           12       0.37      0.12      0.18       288
#
#     accuracy                           0.61      6421
#    macro avg       0.42      0.34      0.36      6421
# weighted avg       0.55      0.61      0.56      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_vcf_features.csv: 47.56%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_vcf_features.csv: 46.71%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.64      3054
#            1       0.00      0.00      0.00       285
#            2       0.00      0.00      0.00       276
#            3       0.00      0.00      0.00       302
#            4       0.00      0.00      0.00       275
#            5       0.00      0.00      0.00       267
#            6       0.00      0.00      0.00       314
#            7       0.00      0.00      0.00       293
#            8       0.00      0.00      0.00       297
#            9       0.00      0.00      0.00       264
#           10       0.00      0.00      0.00       259
#           11       0.00      0.00      0.00       247
#           12       0.00      0.00      0.00       288
#
#     accuracy                           0.48      6421
#    macro avg       0.04      0.08      0.05      6421
# weighted avg       0.23      0.48      0.31      6421
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda2023\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tf_energy_features.csv: 58.88%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tf_energy_features.csv: 58.28%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.81      3054
#            1       0.38      0.29      0.33       285
#            2       0.44      0.36      0.39       276
#            3       0.37      0.19      0.25       302
#            4       0.39      0.47      0.43       275
#            5       0.40      0.39      0.39       267
#            6       0.42      0.24      0.30       314
#            7       0.38      0.11      0.17       293
#            8       0.42      0.27      0.32       297
#            9       0.24      0.08      0.12       264
#           10       0.14      0.03      0.05       259
#           11       0.39      0.38      0.38       247
#           12       0.37      0.11      0.17       288
#
#     accuracy                           0.59      6421
#    macro avg       0.39      0.30      0.32      6421
# weighted avg       0.52      0.59      0.53      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Domain_Feature.csv: 70.27%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Domain_Feature.csv: 72.02%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87      3054
#            1       0.55      0.54      0.55       285
#            2       0.63      0.65      0.64       276
#            3       0.51      0.34      0.41       302
#            4       0.63      0.63      0.63       275
#            5       0.66      0.70      0.68       267
#            6       0.59      0.46      0.52       314
#            7       0.53      0.35      0.42       293
#            8       0.59      0.43      0.50       297
#            9       0.54      0.35      0.42       264
#           10       0.52      0.28      0.36       259
#           11       0.55      0.51      0.53       247
#           12       0.54      0.26      0.35       288
#
#     accuracy                           0.70      6421
#    macro avg       0.59      0.50      0.53      6421
# weighted avg       0.67      0.70      0.68      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Frequency_Domain_Feature.csv: 64.85%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Frequency_Domain_Feature.csv: 66.45%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87      3054
#            1       0.38      0.44      0.40       285
#            2       0.56      0.56      0.56       276
#            3       0.36      0.32      0.34       302
#            4       0.55      0.56      0.55       275
#            5       0.51      0.50      0.51       267
#            6       0.51      0.40      0.45       314
#            7       0.38      0.23      0.28       293
#            8       0.49      0.34      0.40       297
#            9       0.38      0.22      0.28       264
#           10       0.39      0.16      0.23       259
#           11       0.45      0.49      0.47       247
#           12       0.34      0.12      0.18       288
#
#     accuracy                           0.65      6421
#    macro avg       0.47      0.41      0.42      6421
# weighted avg       0.61      0.65      0.62      6421
#
# Accuracy for testing on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv: 73.71%
# Accuracy for training on C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv: 77.78%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      3054
#            1       0.56      0.63      0.59       285
#            2       0.69      0.73      0.71       276
#            3       0.54      0.46      0.50       302
#            4       0.68      0.65      0.67       275
#            5       0.67      0.70      0.68       267
#            6       0.60      0.52      0.55       314
#            7       0.58      0.41      0.48       293
#            8       0.62      0.51      0.56       297
#            9       0.57      0.42      0.48       264
#           10       0.57      0.35      0.43       259
#           11       0.63      0.57      0.60       247
#           12       0.54      0.34      0.41       288
#
#     accuracy                           0.74      6421
#    macro avg       0.62      0.56      0.58      6421
# weighted avg       0.72      0.74      0.72      6421

# %%
import pandas as pd  # For data handling
import numpy as np  # For numerical operations
from sklearn.model_selection import KFold  # For cross-validation
from sklearn.preprocessing import StandardScaler  # For scaling the data
from sklearn.svm import SVC  # For the SVM model
from sklearn.metrics import accuracy_score  # For model evaluation
import matplotlib.pyplot as plt  # For plotting

# List of data files with paths
files = {
    


    
    'MAV_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mav_features.csv',
    'RMS_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_rms_features.csv',
    'VAR_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_var_features.csv',
    'WL_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wl_features.csv',
    'ZC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_zc_features.csv',
    'SSC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_ssc_features.csv',
    'WAMP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wamp_features.csv',
    
    
    'MNF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mnf_features.csv',
    'MDF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mdf_features.csv',
    'PF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_pf_features.csv',
    'PSD_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_psd_features.csv',
    'TP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tp_features.csv',
    
    
    
    'WT_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tf_energy_features.csv',
    
    
    'Combined_Time_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Domain_Feature.csv',
    'Combined_Fequency_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Frequency_Domain_Feature.csv',
    'combined_Time_Freq_& Tim-Freq_domain':r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv',
    
}





# Function to train and evaluate a classifier using cross-validation on a given dataset
def train_and_evaluate(file, label='Class'):
    try:
        # Step 1: Load the dataset
        data = pd.read_csv(file)
        
        # Step 2: Split the dataset into features and target variable
        X = data.drop(label, axis=1)
        Y = data[label]

        # Standardize the features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Initialize the SVM Classifier
        classifier = SVC(kernel='linear', random_state=42)

        # Perform cross-validation and calculate mean accuracy and standard deviation
        kf = KFold(n_splits=10, shuffle=True, random_state=42)
        test_accuracies = []
        
        for train_index, test_index in kf.split(X_scaled):
            X_train, X_test = X_scaled[train_index], X_scaled[test_index]
            Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
            
            classifier.fit(X_train, Y_train)
            Y_pred = classifier.predict(X_test)
            test_accuracies.append(accuracy_score(Y_test, Y_pred))
        
        mean_test_accuracy = np.mean(test_accuracies)
        std_test_accuracy = np.std(test_accuracies)

        return (mean_test_accuracy, std_test_accuracy)

    except FileNotFoundError:
        print(f"File not found: {file}")
        return None
    except Exception as e:
        print(f"An error occurred while processing {file}: {e}")
        return None

# Train and evaluate a classifier for each dataset and collect the results
results = {}

for label, file in files.items():
    test_res = train_and_evaluate(file)
    if test_res is not None:
        results[label] = {'test': test_res}
    else:
        print(f"Skipping dataset: {label} due to errors")

# Plot the comparison results with error bars
fig, ax = plt.subplots(figsize=(15, 8))

labels = list(results.keys())
test_means = [results[label]['test'][0] for label in labels]
test_stds = [results[label]['test'][1] for label in labels]

x = np.arange(len(labels))  # the label locations
width = 0.6  # the width of the bars

rects = ax.bar(x, test_means, width, yerr=test_stds, capsize=5, color='lightblue', ecolor='black', edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Feature Datasets')
ax.set_ylabel('Mean Testing Accuracy')
ax.set_title('Mean Testing Accuracy with Error Bar for Different Feature Datasets')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)

# Function to add values on top of the bars
def autolabel(rects, means, stds):
    for rect, mean, std in zip(rects, means, stds):
        height = rect.get_height()
        ax.annotate(f'{mean:.2f} ± {std:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

autolabel(rects, test_means, test_stds)

fig.tight_layout()
plt.show()

# Print results
for label, (mean, std) in zip(labels, zip(test_means, test_stds)):
    print(f'\nResults for {label}:')
    print(f'Mean Test Accuracy: {mean:.2%}')
    print(f'Standard Deviation of Test Accuracy: {std:.2%}')
# Out:
# Results for MAV_Features:
# Mean Test Accuracy: 59.78%
# Standard Deviation of Test Accuracy: 1.10%
#
# Results for RMS_Features:
# Mean Test Accuracy: 61.07%
# Standard Deviation of Test Accuracy: 0.88%
#
# Results for VAR_Features:
# Mean Test Accuracy: 59.91%
# Standard Deviation of Test Accuracy: 0.79%
#
# Results for WL_Features:
# Mean Test Accuracy: 58.88%
# Standard Deviation of Test Accuracy: 1.13%
#
# Results for ZC_Features:
# Mean Test Accuracy: 46.97%
# Standard Deviation of Test Accuracy: 1.15%
#
# Results for SSC_Features:
# Mean Test Accuracy: 46.97%
# Standard Deviation of Test Accuracy: 1.15%
#
# Results for WAMP_Features:
# Mean Test Accuracy: 54.35%
# Standard Deviation of Test Accuracy: 1.00%
#
# Results for MNF_Features:
# Mean Test Accuracy: 49.43%
# Standard Deviation of Test Accuracy: 1.46%
#
# Results for MDF_Features:
# Mean Test Accuracy: 51.17%
# Standard Deviation of Test Accuracy: 1.35%
#
# Results for PF_Features:
# Mean Test Accuracy: 48.73%
# Standard Deviation of Test Accuracy: 1.20%
#
# Results for PSD_Features:
# Mean Test Accuracy: 61.82%
# Standard Deviation of Test Accuracy: 0.91%
#
# Results for TP_Features:
# Mean Test Accuracy: 61.83%
# Standard Deviation of Test Accuracy: 0.91%
#
# Results for VCF_Features:
# Mean Test Accuracy: 46.97%
# Standard Deviation of Test Accuracy: 1.15%
#
# Results for WT_Features:
# Mean Test Accuracy: 58.31%
# Standard Deviation of Test Accuracy: 1.09%
#
# Results for Combined_Time_domain:
# Mean Test Accuracy: 70.22%
# Standard Deviation of Test Accuracy: 0.86%
#
# Results for Combined_Fequency_domain:
# Mean Test Accuracy: 65.33%
# Standard Deviation of Test Accuracy: 0.66%
#
# Results for combined_Time_Freq_& Tim-Freq_domain:
# Mean Test Accuracy: 73.55%
# Standard Deviation of Test Accuracy: 0.82%

# %%
import pandas as pd  # For data handling
import numpy as np  # For numerical operations
from sklearn.model_selection import KFold  # For cross-validation
from sklearn.preprocessing import StandardScaler  # For scaling the data
from sklearn.svm import SVC  # For SVM model
from sklearn.metrics import accuracy_score  # For model evaluation
import matplotlib.pyplot as plt  # For plotting
import time  # For measuring time

# List of data files with paths
files = {
    


    
    'MAV_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mav_features.csv',
    'RMS_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_rms_features.csv',
    'VAR_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_var_features.csv',
    'WL_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wl_features.csv',
    'ZC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_zc_features.csv',
    'SSC_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_ssc_features.csv',
    'WAMP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_wamp_features.csv',
    
    
    'MNF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mnf_features.csv',
    'MDF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_mdf_features.csv',
    'PF_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_pf_features.csv',
    'PSD_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_psd_features.csv',
    'TP_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tp_features.csv',
    
    
    
    'WT_Features': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\all_tf_energy_features.csv',
    
    
    'Combined_Time_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Domain_Feature.csv',
    'Combined_Fequency_domain': r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Frequency_Domain_Feature.csv',
    'combined_Time_Freq_& Tim-Freq_domain':r'C:\Users\c3054367\OneDrive - Newcastle University\lab\July\25072024\Combined\Matlab\Output_2507_50_25\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv',
    
}




# Function to measure processing times for SVM on a given dataset with cross-validation
def measure_processing_times(file, label='Class'):
    timings = {'Load Time': 0, 'Scaler Time': 0, 'SVM Training Time': 0, 'Cross-Val Time': 0, 'Total Time': 0}

    try:
        # Measure Load Time
        start_time = time.time()
        data = pd.read_csv(file)
        timings['Load Time'] = time.time() - start_time

        # Split the dataset into features and target variable
        X = data.drop(label, axis=1)
        Y = data[label]

        # Standardize the features
        start_time = time.time()
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        timings['Scaler Time'] = time.time() - start_time

        # Initialize the SVM Classifier
        classifier = SVC(kernel='linear', random_state=42)

        # Perform cross-validation and measure the time
        kf = KFold(n_splits=10, shuffle=True, random_state=42)
        start_time = time.time()
        
        for train_index, test_index in kf.split(X_scaled):
            X_train, X_test = X_scaled[train_index], X_scaled[test_index]
            Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
            
            # Measure SVM Training Time
            train_start_time = time.time()
            classifier.fit(X_train, Y_train)
            timings['SVM Training Time'] += time.time() - train_start_time
            
            classifier.predict(X_test)
        
        end_time = time.time()
        timings['Cross-Val Time'] = end_time - start_time

        # Calculate Total Time (excluding cross-validation time)
        timings['Total Time'] = timings['Load Time'] + timings['Scaler Time'] + timings['SVM Training Time']

        # Print timing results
        print(f'\nTiming Results for {file}:')
        print(f'Load Time: {timings["Load Time"]:.2f} seconds')
        print(f'Scaler Time: {timings["Scaler Time"]:.2f} seconds')
        print(f'SVM Training Time: {timings["SVM Training Time"]:.2f} seconds')
        print(f'Cross-Validation Time: {timings["Cross-Val Time"]:.2f} seconds')
        print(f'Total Time Without CV: {timings["Total Time"]:.2f} seconds\n')

        # Return the timings for plotting
        return timings

    except FileNotFoundError:
        print(f"File not found: {file}")
    except Exception as e:
        print(f"An error occurred while processing {file}: {e}")
        return None

# Measure processing times for each dataset and collect the results
results = {}

for label, file in files.items():
    timings = measure_processing_times(file)
    if timings is not None:
        results[label] = timings
    else:
        print(f"Skipping dataset: {label} due to errors")

# Extract labels for plotting
labels = list(results.keys())

# Plot processing time
fig, ax2 = plt.subplots(figsize=(15, 8))

load_times = [results[label]['Load Time'] for label in labels]
scaler_times = [results[label]['Scaler Time'] for label in labels]
svm_train_times = [results[label]['SVM Training Time'] for label in labels]
cross_val_times = [results[label]['Cross-Val Time'] for label in labels]
total_times = [results[label]['Total Time'] for label in labels]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

bars1 = ax2.bar(x - 2*width, load_times, width, label='Load Time', color='blue', edgecolor='black')
bars2 = ax2.bar(x - width, scaler_times, width, label='Scaler Time', color='green', edgecolor='black')
bars3 = ax2.bar(x, svm_train_times, width, label='SVM Training Time', color='coral', edgecolor='black')
bars4 = ax2.bar(x + width, total_times, width, label='Total Time Without CV', color='red', edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_xlabel('Datasets')
ax2.set_ylabel('Time Taken (seconds)')
ax2.set_title('Processing Time for Different Feature Datasets')
ax2.set_xticks(x)
ax2.set_xticklabels(labels, rotation=90)
ax2.legend()

fig.tight_layout()
plt.show()
# Out:
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mav_features.csv:
# Load Time: 0.02 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 53.34 seconds
# Cross-Validation Time: 57.09 seconds
# Total Time Without CV: 53.37 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_rms_features.csv:
# Load Time: 0.02 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 50.04 seconds
# Cross-Validation Time: 53.60 seconds
# Total Time Without CV: 50.06 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_var_features.csv:
# Load Time: 0.02 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 40.71 seconds
# Cross-Validation Time: 44.19 seconds
# Total Time Without CV: 40.74 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wl_features.csv:
# Load Time: 0.01 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 59.00 seconds
# Cross-Validation Time: 62.70 seconds
# Total Time Without CV: 59.02 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_zc_features.csv:
# Load Time: 0.01 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 46.87 seconds
# Cross-Validation Time: 50.48 seconds
# Total Time Without CV: 46.88 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_ssc_features.csv:
# Load Time: 0.01 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 71.43 seconds
# Cross-Validation Time: 75.52 seconds
# Total Time Without CV: 71.44 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_wamp_features.csv:
# Load Time: 0.01 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 67.88 seconds
# Cross-Validation Time: 71.77 seconds
# Total Time Without CV: 67.89 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mnf_features.csv:
# Load Time: 0.02 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 77.39 seconds
# Cross-Validation Time: 81.31 seconds
# Total Time Without CV: 77.41 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_mdf_features.csv:
# Load Time: 0.02 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 63.77 seconds
# Cross-Validation Time: 67.63 seconds
# Total Time Without CV: 63.80 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_pf_features.csv:
# Load Time: 0.01 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 62.08 seconds
# Cross-Validation Time: 65.85 seconds
# Total Time Without CV: 62.09 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_psd_features.csv:
# Load Time: 0.03 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 50.06 seconds
# Cross-Validation Time: 53.58 seconds
# Total Time Without CV: 50.10 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tp_features.csv:
# Load Time: 0.03 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 49.77 seconds
# Cross-Validation Time: 53.28 seconds
# Total Time Without CV: 49.80 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_vcf_features.csv:
# Load Time: 0.03 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 45.51 seconds
# Cross-Validation Time: 49.20 seconds
# Total Time Without CV: 45.54 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\all_tf_energy_features.csv:
# Load Time: 0.03 seconds
# Scaler Time: 0.00 seconds
# SVM Training Time: 63.17 seconds
# Cross-Validation Time: 66.88 seconds
# Total Time Without CV: 63.21 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Domain_Feature.csv:
# Load Time: 0.09 seconds
# Scaler Time: 0.02 seconds
# SVM Training Time: 81.69 seconds
# Cross-Validation Time: 85.72 seconds
# Total Time Without CV: 81.80 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Frequency_Domain_Feature.csv:
# Load Time: 0.11 seconds
# Scaler Time: 0.01 seconds
# SVM Training Time: 112.03 seconds
# Cross-Validation Time: 115.68 seconds
# Total Time Without CV: 112.15 seconds
#
#
# Timing Results for C:\Users\c3054367\OneDrive - Newcastle University\lab\July\20072024\Matlab\Output_1907_200_100\Combined_Time_Freq_and_Time-Freq Domain_Feature.csv:
# Load Time: 0.21 seconds
# Scaler Time: 0.03 seconds
# SVM Training Time: 154.07 seconds
# Cross-Validation Time: 159.62 seconds
# Total Time Without CV: 154.32 seconds
